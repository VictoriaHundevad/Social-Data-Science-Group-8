# %%
#Bruges ikke!
import requests
url = 'https://gomore.dk/rides?from=&from_latitude=&from_longitude=&to=&to_latitude=&to_longitude=&on=2018-08-23T06%3A00%3A00%2B02%3A00'
url = 'https://gomore.dk/rides?from=&from_latitude=&from_longitude=&to=&to_latitude=&to_longitude=&on=2018-08-23T06%3A00%3A00%2B02%3A00'
raw_header = ''':authority: gomore.dk
:method: GET
:path: /rides?from=&from_latitude=&from_longitude=&to=&to_latitude=&to_longitude=&on=2018-08-23T06%3A00%3A00%2B02%3A00
:scheme: https
accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
accept-encoding: gzip, deflate, br
accept-language: da-DK,da;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: max-age=0
cookie: _ga=GA1.2.1458221963.1534491365; remember_user_token=BAhbCFsGaQMvNQJJIiIkMmEkMTAkeXZVNzZtY1NvSUJ2cXRFWEJwRlp1ZQY6BkVUSSIXMTUzNDkyMTUwOC43MDU3OTkzBjsARg%3D%3D--e3c81fef7213d33dd940caa7d362eaa2e16293a3; _gid=GA1.2.1126520593.1534921508; ABTastySession=referrer%3D__landingPage%3Dhttps%3A//gomore.dk/; fbm_172475122803857=base_domain=.gomore.dk; _gomore_session2=...%3D%3D--e740dfb706d02012c23bacd800888094529870aa; ABTasty=uid%3D18081709360344407%26fst%3D1534491363764%26pst%3D1534921506655%26cst%3D1534926872779%26ns%3D7%26pvt%3D56%26pvis%3D5%26th%3D; fbsr_172475122803857=eduakgxNHomYVJ1MZ3MOAQJKeZUiqEYQ8PJn_T3W-jI....
if-none-match: W/"02aacd717f290f08025a59e5a6844e87"
referer: https://gomore.dk/
upgrade-insecure-requests: 1
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'''
session = requests.session()
session.header = raw_header
html = session.get(url).text

# %%
for loc in html.split('href="')[1:]:
    print(loc.split('"')[0])
# Out:
# https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_76-922444e9245179f19c9a4e7be52f100aebfbb169c25cc7f6c68d088a2cf8842b.png
# https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_120-6a6f9541cdd9736f6b3fed4b415933863a1a2341e28970b4777954da57307038.png
# https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_152-2cd5380add454126c621e8663a7ff7fe2cf6ebe8c46707cfd360b5d56f01c640.png
# https://d19xplwbp8p59b.cloudfront.net/assets/application-b97f9804c455aac51b9f7c17a436cad8d3c2ce8ea62752f71cc07680dbc1d69d.css
# https://d19xplwbp8p59b.cloudfront.net/assets/print-71ab271d8e11ac8c82decf5e54365dfdc9c880a1c920d9c7ac7e6a7a2c53d2da.css
# https://d19xplwbp8p59b.cloudfront.net/favicon.ico
# /
# #a
# #c
# /rides
# /biludlejning
# /leasing
# /rides/new
# /users/sign_up
# /users/sign_in
# /rides
# /agents
# /support
# #
# /users/auth/facebook
# /terms
# https://www.facebook.com/gomore.dk
# /users/sign_up
# /users/sign_in
# https://itunes.apple.com/app/gomore/id671759668
# https://play.google.com/store/apps/details?id=dk.gomore
# /about
# /press
# https://blog.gomore.dk
# http://blog.gomore.dk/talent
# /support
# /rideshare/how
# /how/drivers
# /rideshare/safety
# /rules
# /samkoersel
# /rental/how
# /rental/owner
# /rental
# /rental/insurance
# #
# /locales/switch/en
# https://gomore.se/
# https://gomore.no/
# https://amovens.com/
# https://gomore.fr/
# /terms
# /sitemap
# https://www.facebook.com/gomore.dk
# http://twitter.com/gomoreDK
# http://instagram.com/gomore.dk
# http://outdatedbrowser.com/
# #

# %%
from bs4 import BeautifulSoup
url = 'https://gomore.dk/rides/6573645'
soup = BeautifulSoup(requests.get(url).text,'lxml')

# %%
import re
import json
json.loads(soup.find_all('meta',{'content':re.compile('\{+')})[0]['content'])
# Out:
# {'rideId': 6573645,
#  'rideData': {'id': 6573645,
#   'depart_at': '2018-08-23T05:00:00+02:00',
#   'seats': 2,
#   'prefs': {'chat': '1',
#    'kids': '1',
#    'music': '1',
#    'animals': '0',
#    'comfort': '1',
#    'smoking': '0'},
#   'notes': 'Send sms om info. 226664729 tjekker ikke gomore så tit',
#   'free_seats': 2,
#   'user_id': 1749382,
#   'handle_fee_rate': 12.5,
#   'handle_fee_ceiling_factor': 100,
#   'handle_fee_maximum': None,
#   'accept_cash': False,
#   'accept_online_payment': True,
#   'quick_booking': True,
#   'flex_booking': True,
#   'price': 11500,
#   'car_id': None,
#   'currency_id': 1,
#   'distance': 51323,
#   'detour_preference': '5_minutes',
#   'overview_polyline': 'spxrIgxrkAWvJHlD?VDdA[VEHCDo@lEUnBq@xN{@zPo@xMiGiCoEmB[FYAoAe@yC_AaIiC_DeA_CaByJwHkJ}HaBuAg@MYDKj@Kd@yCnHw@lB{@vD{@~DeA|CqBzDc@h@eDfDiAlBsI|Ow@bAiAt@_AXiAL}D?kAP_A\\{@f@eAdAkBbDsAxE[~BUlDoAn[i@hCw@hCmAxBeGhIcDnEkGlIcCfC_CxBkBzAGLgAx@kPvKaElDiCxF_D|Jk@lCc@bCs@hDk@tDu@nCi@pA}@zAqFbHaG|GcIzI_LrM_HlKkSx]iKxQiD~GqCzGuLr\\k[~{@{Lj\\kBlEaF`KqKlTkFpKoFtJeCtD_DbEYZi@n@mBtBgMnK}FpEeDfCmYbUiFpD_FzCeNrHuHlEiKnHaEhDcD~CqCnD}B~D{BtEeDdHuZpp@yR|b@Wr@mChHiEjO_DpNoHra@cBvIoCfL{BzIqGpSqDrJuIpR{H`NwCdEuEtFsCrCmFnEeCnBaEnDgDjDyGlIwEvGcHhJiExEaFbE}FjD}D~A}FzAwFl@kEB}EW{Dq@yIwByHgBkj@kM}GoA{Gg@_GCsERgEf@{HdBkIhDgGpDoDnC_FrEwDfEyEvG{EdI_FbKcGrNyHdSiF`OwGjS{IdZyEpQaHdYaHn[iHl[gFbQ{ErM_FxKwGlLgA~AaGnIeDxDwFxFmOpMcHbFeNvI{O~JmPxKuS|M_\\rSyP|KWDoCnBwB|A}IfHsIbImPrPqHrIoHdJ}KtOaBvBgCzD}B~DaEzGmIdOuL`ViLrW}KhW{F~L_CrEuCvEwHnKwFjGcC~B_HnFqCjBgE|BwEtBoQ`H}LdF{KlFsHfEcM`IqDlCu@j@wG`FwA`AiQpNqEzDaN|KiSnPg@d@[Be@ZmJ|FcBz@cBf@wD\\K?CtCAr@EnBGlYFtIn@~ZVpRKlL{@rL_BtK{BxIsAnDuAvC}M`WiNhWqAjCoAlE_@tCO~DFrEVvCdAdFpBbH`A`FpEh`@xCvWdBvPrKhoA|Dze@XbM^xP`@fS?xJaBtb@}Dpw@g@bNWfXFtZk@fZAxRb@`TvAtf@b@jJz@xLdBnQ|AdO~CzXlBxXjAf\\x@hMbBrQxAvQPbGD~FWzJo@nH{D`WeDdSgAfF_B~EaDhHoC`F}IhOcCjF_B|EwAvFa@dCmGbb@eFjb@sC|X_@tC[bAqA|DOAGDe@i@WGYJkC`D{AlAmAj@sB`@]B@LDh@V^b@dAd@fBDVzEcFb@_@xAgB',
#   'duration': '2831',
#   'waypoints_attributes': [{'id': 22858454,
#     'latitude': 55.6725824,
#     'longitude': 12.5531621,
#     'name': 'Vesterbrogade, København'},
#    {'id': 22858455,
#     'latitude': 55.9456388,
#     'longitude': 12.0486025,
#     'name': 'Kregme (Hillerødvej), Frederiksværk'}]},
#  'routeIcons': {'start': 'https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_a-2c976bcbf350b3bec8d99539513706431cfc717b7e90ab801a78916128390ad2.png',
#   'via': 'https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_via-15c6b6331c533081482d9c4fe22ba87ef452f09fbed2ad6c3430ee261958252f.png',
#   'end': 'https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_b-e11471d2e8ba25da35f6b95c5ab183f3eeacb57a34329a79e8f1a258d63aaa74.png'}}

# %%
soup
#re.findall('\d+',soup.title.text)
# Out:
# <!DOCTYPE html>
# <html class="" lang="da">
# <head>
# <meta charset="utf-8"/>
# <title>Lift fra Vesterbrogade, København til Kregme (Hillerødvej), Frederiksværk for DKK 115</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Michael kører fra Vesterbrogade, København til Kregme (Hillerødvej), Frederiksværk d. 23.08.2018 05:00. Skal du med?" name="description"/>
# <meta content="GoMore" property="og:site_name"/>
# <meta content="Lift fra Vesterbrogade, København til Kregme (Hillerødvej), Frederiksværk for DKK 115" property="og:title"/>
# <meta content="gomoredk:ride" property="og:type"/>
# <meta content='{"rideId":6573645,"rideData":{"id":6573645,"depart_at":"2018-08-23T05:00:00+02:00","seats":2,"prefs":{"chat":"1","kids":"1","music":"1","animals":"0","comfort":"1","smoking":"0"},"notes":"Send sms om info. 226664729 tjekker ikke gomore så tit","free_seats":2,"user_id":1749382,"handle_fee_rate":12.5,"handle_fee_ceiling_factor":100,"handle_fee_maximum":null,"accept_cash":false,"accept_online_payment":true,"quick_booking":true,"flex_booking":true,"price":11500,"car_id":null,"currency_id":1,"distance":51323,"detour_preference":"5_minutes","overview_polyline":"spxrIgxrkAWvJHlD?VDdA[VEHCDo@lEUnBq@xN{@zPo@xMiGiCoEmB[FYAoAe@yC_AaIiC_DeA_CaByJwHkJ}HaBuAg@MYDKj@Kd@yCnHw@lB{@vD{@~DeA|CqBzDc@h@eDfDiAlBsI|Ow@bAiAt@_AXiAL}D?kAP_A\\{@f@eAdAkBbDsAxE[~BUlDoAn[i@hCw@hCmAxBeGhIcDnEkGlIcCfC_CxBkBzAGLgAx@kPvKaElDiCxF_D|Jk@lCc@bCs@hDk@tDu@nCi@pA}@zAqFbHaG|GcIzI_LrM_HlKkSx]iKxQiD~GqCzGuLr\\k[~{@{Lj\\kBlEaF`KqKlTkFpKoFtJeCtD_DbEYZi@n@mBtBgMnK}FpEeDfCmYbUiFpD_FzCeNrHuHlEiKnHaEhDcD~CqCnD}B~D{BtEeDdHuZpp@yR|b@Wr@mChHiEjO_DpNoHra@cBvIoCfL{BzIqGpSqDrJuIpR{H`NwCdEuEtFsCrCmFnEeCnBaEnDgDjDyGlIwEvGcHhJiExEaFbE}FjD}D~A}FzAwFl@kEB}EW{Dq@yIwByHgBkj@kM}GoA{Gg@_GCsERgEf@{HdBkIhDgGpDoDnC_FrEwDfEyEvG{EdI_FbKcGrNyHdSiF`OwGjS{IdZyEpQaHdYaHn[iHl[gFbQ{ErM_FxKwGlLgA~AaGnIeDxDwFxFmOpMcHbFeNvI{O~JmPxKuS|M_\\rSyP|KWDoCnBwB|A}IfHsIbImPrPqHrIoHdJ}KtOaBvBgCzD}B~DaEzGmIdOuL`ViLrW}KhW{F~L_CrEuCvEwHnKwFjGcC~B_HnFqCjBgE|BwEtBoQ`H}LdF{KlFsHfEcM`IqDlCu@j@wG`FwA`AiQpNqEzDaN|KiSnPg@d@[Be@ZmJ|FcBz@cBf@wD\\K?CtCAr@EnBGlYFtIn@~ZVpRKlL{@rL_BtK{BxIsAnDuAvC}M`WiNhWqAjCoAlE_@tCO~DFrEVvCdAdFpBbH`A`FpEh`@xCvWdBvPrKhoA|Dze@XbM^xP`@fS?xJaBtb@}Dpw@g@bNWfXFtZk@fZAxRb@`TvAtf@b@jJz@xLdBnQ|AdO~CzXlBxXjAf\\x@hMbBrQxAvQPbGD~FWzJo@nH{D`WeDdSgAfF_B~EaDhHoC`F}IhOcCjF_B|EwAvFa@dCmGbb@eFjb@sC|X_@tC[bAqA|DOAGDe@i@WGYJkC`D{AlAmAj@sB`@]B@LDh@V^b@dAd@fBDVzEcFb@_@xAgB","duration":"2831","waypoints_attributes":[{"id":22858454,"latitude":55.6725824,"longitude":12.5531621,"name":"Vesterbrogade, København"},{"id":22858455,"latitude":55.9456388,"longitude":12.0486025,"name":"Kregme (Hillerødvej), Frederiksværk"}]},"routeIcons":{"start":"https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_a-2c976bcbf350b3bec8d99539513706431cfc717b7e90ab801a78916128390ad2.png","via":"https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_via-15c6b6331c533081482d9c4fe22ba87ef452f09fbed2ad6c3430ee261958252f.png","end":"https://d19xplwbp8p59b.cloudfront.net/assets/icon_map_b-e11471d2e8ba25da35f6b95c5ab183f3eeacb57a34329a79e8f1a258d63aaa74.png"}}' id="controller-options"/>
# <meta content="Michael kører fra Vesterbrogade, København til Kregme (Hillerødvej), Frederiksværk d. 23.08.2018 05:00. Skal du med?" property="og:description"/>
# <meta content="https://gomore.dk/rides/6573645" property="og:url"/>
# <meta content="https://d19xplwbp8p59b.cloudfront.net/assets/og_image_smile-8e22f5b0c73303a9be6aef94d665eb58956a6eab966c4d25abf83ac06011671a.png" property="og:image"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="172475122803857" property="fb:app_id"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="app-id=671759668" name="apple-itunes-app"/>
# <meta content="app-id=dk.gomore" name="google-play-app"/>
# <meta content="GoMore" name="apple-mobile-web-app-title"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="”always”" name="”referrer”"/>
# <link href="https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_76-922444e9245179f19c9a4e7be52f100aebfbb169c25cc7f6c68d088a2cf8842b.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_120-6a6f9541cdd9736f6b3fed4b415933863a1a2341e28970b4777954da57307038.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://d19xplwbp8p59b.cloudfront.net/assets/icon_smile_152-2cd5380add454126c621e8663a7ff7fe2cf6ebe8c46707cfd360b5d56f01c640.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <!--[if lt IE 9]>
#       <script src="https://html5shim.googlecode.com/svn/trunk/html5.js"></script>
#     <![endif]-->
# <link href="https://d19xplwbp8p59b.cloudfront.net/assets/application-b97f9804c455aac51b9f7c17a436cad8d3c2ce8ea62752f71cc07680dbc1d69d.css" media="all" rel="stylesheet"/>
# <link href="https://d19xplwbp8p59b.cloudfront.net/assets/print-71ab271d8e11ac8c82decf5e54365dfdc9c880a1c920d9c7ac7e6a7a2c53d2da.css" media="print" rel="stylesheet"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="w/8U4THV2xCHzLWClGlaMTAX962GepxW/SiQP9PhAbBpJVzsQizxzPA3vTeVbE0TrvIbpU6THF91EdmCE9TzJA==" name="csrf-token"/>
# <meta content="Vesterbrogade, København → Kregme (Hillerødvej), Frederiksværk" property="gomoredk:route"/>
# <meta content="Michael P." property="gomoredk:driver_name"/>
# <meta content="2" property="gomoredk:available_seats"/>
# <meta content="product" name="twitter:card"/>
# <meta content="@gomoreDK" name="twitter:site"/>
# <meta content="Lift: Vesterbrogade, København → Kregme (Hillerødvej), Frederiksværk" name="twitter:title"/>
# <meta content="Michael P. tilbyder 2 pladser fra Vesterbrogade, København til Kregme (Hillerødvej), Frederiksværk. Vil du med?" name="twitter:description"/>
# <meta content="https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;w=120&amp;h=120&amp;fit=crop" name="twitter:image"/>
# <meta content="115,- DKK" name="twitter:data1"/>
# <meta content="Pris pr. plads" name="twitter:label1"/>
# <meta content="Vesterbrogade, København → Kregme (Hillerødvej), Frederiksværk" name="twitter:data2"/>
# <meta content="Rute" name="twitter:label2"/>
# <link href="https://d19xplwbp8p59b.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="//try.abtasty.com/112fcf862deeba81e497cef0f27baf93.js" type="text/javascript"></script>
# </head>
# <body class="rideshare ">
# <script>
#   dataLayer = [];
#
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KZTJB3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-KZTJB3');</script>
# <!-- End Google Tag Manager -->
# <div id="fb-root"></div>
# <div class=" ">
# <nav class="navbar navbar-default ">
# <div class="container">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/">
# <svg viewbox="0 0 147 32" width="148px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title>GoMore Samkrsel og Biludlejning</title><defs><polygon id="a" points="0 31.957 31.549 31.957 31.549 .065 0 .065"></polygon><polygon id="c" points="109.072 22.283 109.072 0 0 0 0 22.283"></polygon></defs><g fill="none" fill-rule="evenodd" transform="translate(-1)"><g transform="translate(116.436)"><path d="M8.89 15.63H9c.36-.05.6-.3.76-.45l.02-.02a.9.9 0 0 0 .25-.56s.17-1 .42-1.43a.9.9 0 0 0 .09-.77 1 1 0 0 0-.55-.55c-.04-.02-.07-.07-.08-.19-.04-.3-.09-1.12-.1-1.21a1.12 1.12 0 0 0-1.16-1.06h-.1c-.29.02-.7.08-.98.4a1 1 0 0 0-.25.8c.04.42-.05.65-.01 1.09v.22a29.93 29.93 0 0 0 .26 2.55c.02.18.12.54.41.82.22.21.59.36.9.36" fill="#FFFFFF"></path><mask fill="white" id="b"><use xlink:href="#a"></use></mask><path d="M13 12.02l.06.11c.2.4.6.65 1.04.65.14 0 .28-.02.42-.07.28-.1.8-.4.8-1.2 0-.46 0-.93.02-1.28l.03-.53.02-.27c0-.2-.06-.4-.06-.61V8.8c-.1-.92-.76-1.11-1.13-1.15-.76-.08-1.35.36-1.5 1.07l-.07.4c-.09.47-.17.95-.13 1.45.05.53.3 1.01.5 1.44" fill="#FFFFFF" mask="url(#b)"></path><path d="M11 29.3c-9.14-2.27-8.02-12.32-7.88-13.62.27-2.21.86-4.48 1.72-6.73.26-.7.55-1.36 1.1-1.85.24-.2.3-.47.34-.63 0-.04.04-.17.1-.24.05-.07.43-.34.65-.49 1.19-.81 2.3-1.59 3.54-2.18a9.28 9.28 0 0 1 3.8-.86c2.42-.08 4.95.28 7.82 1.1a7.56 7.56 0 0 1 3.44 2.07c.18.19.25.37.26.64a6.2 6.2 0 0 1-.62 3.01c-.28.58-1.08 2.63-1.27 3.05a44.6 44.6 0 0 1-1.6 3.26 9.44 9.44 0 0 1-3.78 3.53c-1.06.6-4.82 2.64-5.61 3.08-.63.35-1.29.52-2.02.52-.31 0-.65-.03-.99-.1-.25-.04-.85-.2-.86-.2-.35-.08-.96-.2-1.26.24l-.06.09c-.15.26.07 1.6 1.63 1.84.41.06.82.1 1.23.1 1.29.02 2.4-.23 3.38-.76.38-.2 4.52-2.42 6.2-3.36A10.64 10.64 0 0 0 24.7 16l2.92-6.11c.32 1.17.64 2.37.87 3.56.18.9.23 1.83.14 2.82v.04c-2 13.35-13.53 13.42-16.98 13.09l-.67-.1zm20.37-16.2a31.54 31.54 0 0 0-2.26-6.97c-.24-.48-.4-1.2-.4-1.2.06-.45-.07-.9-.35-1.25a1.84 1.84 0 0 0-1.13-.67c-.14-.02-.29-.04-.47-.04-.12 0-.24 0-.36.03a9.35 9.35 0 0 0-1.6-1.1c-.67-.36-1.34-.5-1.95-.64-1.28-.31-6.52-1.2-7.96-1.2-.4 0-.79.02-1.18.04-2.44.12-4.55.83-6.46 2.17L5.01 3.8c-1.17.8-2.09 1.56-2.84 2.37-.83.77-1.83 1.78-1.51 2.9.13.5.4.81.7.99A30.2 30.2 0 0 0 0 16.99c0 2.85 1.07 11.83 8.44 14.3.01 0 1.1.33 1.65.45.26.05.46.1.73.13.27.05 1.1.08 1.12.08 4.08.13 15.42-.76 18.74-11.7 0 0 .43-1.45.57-2.2a18 18 0 0 0 .28-2.36c.05-.82 0-1.67-.16-2.58z" fill="#FFFFFF" mask="url(#b)"></path></g><g transform="translate(0 3.444)"><mask fill="white" id="d"><use xlink:href="#c"></use></mask><path d="M68.22 14.03a4.08 4.08 0 0 1 4.12-4.06c2.28 0 4.12 1.8 4.12 4.06a4.08 4.08 0 0 1-4.12 4.06 4.08 4.08 0 0 1-4.12-4.06zm-4.25 0a8.3 8.3 0 0 0 8.37 8.25 8.3 8.3 0 0 0 8.37-8.25 8.3 8.3 0 0 0-8.37-8.25 8.3 8.3 0 0 0-8.37 8.25zm-36.08 0a4.08 4.08 0 0 1 4.12-4.06c2.3 0 4.12 1.8 4.12 4.06a4.08 4.08 0 0 1-4.12 4.06 4.08 4.08 0 0 1-4.12-4.06zm-4.25 0a8.3 8.3 0 0 0 8.37 8.25 8.3 8.3 0 0 0 8.37-8.25 8.3 8.3 0 0 0-8.37-8.25 8.3 8.3 0 0 0-8.37 8.25zm38.52 8.08V1.6h-4.2L52.17 12.7 46.4 1.62H42.2V22.1h4.14V9.78l4.54 8.86h2.6l4.55-8.86V22.1h4.14zM20.63 5.44A10.56 10.56 0 0 0 11.86 1C5.74 1 1 5.56 1 11.56 1 17 5.3 22.27 11.41 22.27c4.08 0 6.33-2.79 6.33-2.79v2.63h4.22V10.94H11.6v4.03h5.78c-.55 1.29-2.9 3.14-5.66 3.14-3.56 0-6.31-3.08-6.31-6.55a6.26 6.26 0 0 1 6.45-6.41c2.5 0 4.16 1.24 5.29 2.78l3.48-2.49zm80.11 4.04c1.91 0 3.26 1.3 3.5 2.87h-7.1a3.53 3.53 0 0 1 3.6-2.87zm3.35 7.36c-.62 1.06-1.9 1.64-3.21 1.64a3.73 3.73 0 0 1-3.78-3.15h11.97v-.17c0-6.48-4.04-9.38-8.33-9.38a8.11 8.11 0 0 0-8.26 8.25 8.13 8.13 0 0 0 8.33 8.24c3.06 0 5.7-1.18 7.28-3.66l-4-1.77zm-12.02-6.6V6.03h-.57c-2 0-4.12 1.03-4.75 2.74V6.22h-4.43v15.89h4.57v-7.6c0-2.77 2.48-4.26 5.18-4.26z" fill="#FFFFFF" mask="url(#d)"></path></g></g></svg>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbar-collapse">
# <ul class="nav navbar-nav primary mb0-sm">
# <li class="active">
# <a href="/rides">Samkørsel</a>
# </li>
# <li class="">
# <a href="/biludlejning">Biludlejning</a>
# </li>
# <li class="">
# <a href="/leasing">Leasing</a>
# </li>
# </ul>
# <ul class="nav navbar-nav navbar-right secondary mb0-sm logged-out">
# <li>
# <a class="btn-nav" href="/rides/new">  Tilbyd lift
# </a>
# </li>
# <li class="nav-separator"></li>
# <li><a href="/users/sign_up" rel="no-follow">Opret profil</a></li>
# <li><a href="/users/sign_in" rel="no-follow">Log ind</a></li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="navsub">
# <div class="container">
# <ul class="list-unstyled list-inline">
# <li class=""><span class=""><a href="/rides">Lift</a></span></li>
# <li class=""><span class=""><a href="/agents">Passagerer</a></span></li>
# <li class="pull-right">
# <a href="/support">Support</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <header class="bg-white bs2 relative">
# <div class="container mv4">
# <div class="flex-sm flex-row-sm">
# <div class="flex-grow-sm">
# <h1 class="mb1 f2">
#             København
#             <span class="fa fa-long-arrow-right mh1 f4 text-gray-20"></span>
#             Frederiksværk
#           </h1>
# <div class="text-gray-40">
#             Torsdag,
#             23. august 2018
#               kl.
#               <span class="text-semi-bold text-gray-70">
#                 05:00
#               </span>
# </div>
# </div>
# <div class="flex flex-wrap flex-nowrap-sm flex-align-center">
# <div class="btn-group hidden-xs">
# <button aria-expanded="false" aria-haspopup="true" class="btn btn-default dropdown-toggle block inline-sm mb2 mb0-sm text-gray-60" data-toggle="dropdown" type="button">
#               Del lift
#             </button>
# <ul class="dropdown-menu dropdown-menu-right mb0">
# <li>
# <a class="f6 js-facebook-share" data-link="https://gomore.dk/rides/6573645" href="#">
#                   Facebook
# </a> </li>
# <li>
# <a class="f6" href="javascript: void(0)" onclick="window.open('https://twitter.com/home?status=Snup et @gomoreDK lift København → Frederiksværk 23/8 kl. 05:00 for DKK 115: https://gomore.dk/rides/6573645','sharer','toolbar=0,status=0,width=580,height=325');">
#                    Twitter
#                  </a>
# </li>
# <li>
# <a class="f6 js-facebook-send" data-link="https://gomore.dk/rides/6573645" href="#">
#                   Messenger
# </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="main main--dark">
# <div class="container">
# <div class="row">
# <div class="col-md-8 ph0 ph4-sm">
# <div class="card mb4 pa0 ba b--gray-7 br0 br1-sm">
# <div class="ph5 pv4 flex bb b--gray-7 bg-gray-5 br1-sm br0-bottom">
# <h3 class="mb0 f4 text-semi-bold flex-grow">
#         Rute
#       </h3>
# </div>
# <div class="route-details">
# <div class="flex flex-align-center mb7">
# <div class="mr3 ml0 ml4-sm minw-48 w-48 text-right text-gray-40">
#           05:00
#         </div>
# <div class="bg-white mr4 pv2">
# <img alt="Icon from" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_from-c44be647593819ac81e7b76a89824b1e7ec719d0845971cc416077f6790af4ce.svg" width="24"/>
# </div>
# <div class="lh-solid">
# <h3 class="f-base text-semi-bold mb1">
#             København
#           </h3>
# <p class="mb0 text-gray-40">
#               Vesterbrogade, København
#             </p>
# </div>
# </div>
# <div class="flex flex-align-center">
# <div class="mr3 ml0 ml4-sm minw-48 w-48 text-right text-gray-40">
# <span class="tilde">~</span>05:50
#         </div>
# <div class="bg-white mr4 pv2">
# <img alt="Icon to" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_to-2f32e0ee0b777aaa8529a554b1be795fb78998af72b3f12da15ddca110a9091e.svg" width="24"/>
# </div>
# <div class="lh-solid">
# <h3 class="f-base text-semi-bold mb1">
#             Frederiksværk
#           </h3>
# <p class="mb0 text-gray-40">
#               Kregme (Hillerødvej), Frederiksværk
#             </p>
# </div>
# </div>
# </div>
# <div class="hidden-xs">
# <a class="js-map-trigger pv4 block text-blue link-unstyled bg-gray-3:hover text-center text-semi-bold" href="#">
#         Se rute på kort
# </a> </div>
# </div>
# <div class="card mb4 pa4 pa5-sm ba b--gray-7 br0 br1-sm z-1 relative">
# <div class="left-quote " id="js-notes">
# <h5 class="mb2 text-gray-60">
#           Bilistens kommentar
#         </h5>
# <p class="mb2 f4 text-gray-70">
#             Send sms om info. 226664729 tjekker ikke gomore så tit
#           </p>
# </div>
# </div>
# <div class="card mb4 pa0 ba b--gray-7 br0 br1-sm">
# <div class="ph5 pv4 bb b--gray-7 bg-gray-5 br1-sm br0-bottom">
# <h3 class="mb0 f4 text-semi-bold">
#         Bilist
#       </h3>
# </div>
# <div class="flex-sm">
# <div class="pa5 pr6-sm pb4 flex flex-column flex-align-center bb bnb-sm b--gray-7">
# <div class="profile-image relative">
# <a href="/profiles/1749382">
# <img alt="Billede af Michael P." class="br-circle" height="120" max_width="120" sizes="120px" src="https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;fit=crop&amp;h=120&amp;w=120" srcset="https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;fit=crop&amp;h=100&amp;w=100 100w, https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;fit=crop&amp;h=120&amp;w=120 120w, https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;fit=crop&amp;h=240&amp;w=240 240w, https://gomore.imgix.net/uploads/user/avatar/1749382/avatar_1519988243.jpg?ixlib=rails-2.1.2&amp;fit=crop&amp;h=360&amp;w=360 360w" width="120"/>
# </a> </div>
# <div class="f6 mt3 mb4 mb0-sm text-gray-40">
#             Ingen anmeldelser
#           </div>
# <a class="btn btn-default btn-block pv3 hidden-sm hidden-md hidden-lg" href="/profiles/1749382">
#           Vis profil
# </a> </div>
# <div class="pa5">
# <h2 class="f3">
# <a class="link-unstyled block relative text-capitalize" href="/profiles/1749382">
#             Michael P.
# </a> </h2>
# <div class="mb2 text-gray-60">
# <div class="inline-sm">
# </div>
# <div class="inline-sm">
#             Medlem siden juni 2017
#           </div>
# </div>
# <div class="mb5 flex-md">
# <div class="mr7-md text-semi-bold text-dark-blue flex flex-align-center">
# <img alt="Icon 16 facebook" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_facebook-1525247a86bccc36fc27944a857adb3da8b729ad41e23fb323408eba0aaec9ca.svg" width="16"/>
#               Facebook-verificeret
#             </div>
# <div class="mr7-md text-semi-bold text-dark-blue flex flex-align-center">
# <img alt="Icon 16 allowed" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_allowed-3f4456da0052a2b6cb5c346873f5d26d60dff3db2beb3dbd2dd748e41ea8ad46.svg" width="16"/>
#               Verificeret telefonnummer
#             </div>
# </div>
# <a class="btn btn-default block inline-sm text-gray-60" href="#" id="js-message-button">Send besked</a>
# </div>
# </div>
# </div>
# <div class="card mb4 pa0 ba b--gray-7 br0 br1-sm">
# <div class="ph5 pv4 bb b--gray-7 bg-gray-5 br1-sm br0-bottom">
# <h3 class="mb0 f4 text-semi-bold">
#         Detaljer og præferencer
#       </h3>
# </div>
# <div class="pv1 ph7">
# <div class="row pv4 bb b--gray-7">
# <div class="col-sm-4 pl0 mb2 mb0-sm text-gray-80 text-semi-bold flex flex-align-center">
# <img alt="" class="mr3 mr4-sm" height="24" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_24_detour-5fd431523a2ecdf1c2ed5e62a89fb1943accb202d447e54ddf7cec823d16fe20.svg" width="24"/>
#           Afvigelse fra ruten
#         </div>
# <div class="col-sm-8 pl0">
#           Max. 5 minutter fra ruten
#         </div>
# </div>
# <div class="row pv4 bb b--gray-7">
# <div class="col-sm-4 pl0 mb2 mb0-sm text-gray-80 text-semi-bold flex flex-align-center">
# <img alt="" class="mr3 mr4-sm" height="24" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_24_car-390094a3efe84a9199fe474052ec8eddbf5f2f561890413b1d52d600ed7420a3.svg" width="24"/>
#           Bil
#         </div>
# <div class="col-sm-8 pl0">
#             -
#         </div>
# </div>
# <div class="row pv4 bb b--gray-7">
# <div class="col-sm-4 pl0 mb2 mb0-sm text-gray-80 text-semi-bold flex flex-align-center">
# <img alt="" class="mr3 mr4-sm" height="24" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_24_comfort-b4883c1a382256d3551a662f45f23727d960fd9c39d47153dcac26e91f9f7c2c.svg" width="24"/>
#             Komfort
#           </div>
# <div class="col-sm-8 pl0">
# <p class="mb0">
#               Bilisten garanterer max. 2 passagerer på bagsædet
#             </p>
# </div>
# </div>
# <div class="row pv4">
# <div class="col-sm-4 pl0 mb2 mb0-sm text-gray-80 text-semi-bold flex flex-align-center">
# <img alt="" class="mr3 mr4-sm" height="24" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_24_preferences-8b3cedfd689f2c7e978104e335772fe8acdd9eb56fe77d13b2f8bfeec5854108.svg" width="24"/>
#           Præferencer
#         </div>
# <div class="col-sm-8 pl0">
# <div class="row pb3">
# <div class="col-xs-6">
# <div class="flex flex-align-center">
# <img alt="Icon 16 allowed" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_allowed-3f4456da0052a2b6cb5c346873f5d26d60dff3db2beb3dbd2dd748e41ea8ad46.svg" width="16"/>
#   Musik
# </div>
# </div>
# <div class="col-xs-6">
# <div class="flex flex-align-center">
# <img alt="Icon 16 disallowed" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_disallowed-727093565cdc6e80edd5d79e71b6a586e799b361f8651952981f3abc68432508.svg" width="16"/>
#   Kæledyr
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-6">
# <div class="flex flex-align-center">
# <img alt="Icon 16 disallowed" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_disallowed-727093565cdc6e80edd5d79e71b6a586e799b361f8651952981f3abc68432508.svg" width="16"/>
#   Rygning
# </div>
# </div>
# <div class="col-xs-6">
# <div class="flex flex-align-center">
# <img alt="Icon 16 allowed" class="mr2" height="16" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_16_allowed-3f4456da0052a2b6cb5c346873f5d26d60dff3db2beb3dbd2dd748e41ea8ad46.svg" width="16"/>
#   Børn
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 ph0 ph4-sm sticky t5 z-1">
# <div class="card mb4 pa0 bt-3 br0 br1-sm b--green">
# <div class="pt5 ph5">
# <h2 class="f4 mt0 mb1 text-center">
#         2 ledige pladser
#       </h2>
# <ul class="list-unstyled mb0">
# <li class="pv3 pr4 flex flex-align-center bb b--paper">
# <img alt="User thumb v3 default" class="br-circle mr3" height="40" src="https://d19xplwbp8p59b.cloudfront.net/assets/user_thumb_v3_default-bc4b613d1f9ce27d3cfe66f10a3f26848b0b85b0f3df9dd53eac0dcf25cbd646.jpg" width="40"/>
#             Dig?
#           </li>
# <li class="pv3 pr4 flex flex-align-center">
# <img alt="User thumb v3 default" class="br-circle mr3" height="40" src="https://d19xplwbp8p59b.cloudfront.net/assets/user_thumb_v3_default-bc4b613d1f9ce27d3cfe66f10a3f26848b0b85b0f3df9dd53eac0dcf25cbd646.jpg" width="40"/>
#             Dig?
#           </li>
# </ul>
# </div>
# <div class="pa4 bt br1-sm br0-top b--gray-7 bg-gray-5">
# <div class="mb4 flex">
# <div class="flex flex-grow flex-align-center">
#           Pris pr. plads
#         </div>
# <div>
# <span class="text-gray-40 text-normal">DKK</span> <span class="f1 text-bold">115</span>
# </div>
# </div>
# <div class="fixed static-md l0 b0 r0 z-1">
# <a class="btn btn-success btn-lg btn-block br0 br1-md" data-toggle="modal" href="#login">
#             Start booking
#           </a>
# </div>
# </div>
# </div>
# <div class="card mb4 mv4 pv4 ph5 flex-md br0 br1-sm text-center text-left-md">
# <div class="icon-points mr4 mb2 pa4"></div>
# <div>
# <h5 class="mb1">
#           Book liftet og tjen <span class="text-pink">12</span> point
#         </h5>
# <p class="mb0 text-gray-40">
#           Brug dine GoMore Point og få rabat på din næste lejebil.
#           <a class="block text-pink" href="/points/how">
#             Læs mere
# </a> </p>
# </div>
# </div>
# <div class="card mb3 pa0 br0 br1-sm">
# <div class="panel mb0 relative">
# <div class="panel-heading mb0 pv4 ph5">
# <a class="panel-toggle panel-toggle--compact collapsed link-unstyled pa0 flex flex-align-center maxw-95% bg-white text-semi-bold" data-parent="#questions" data-toggle="collapse" href="#q1">
# <img alt="Icon 24 online payment" class="mr3" height="24" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_24_online_payment-5807f13cedfdfa15471fdc820f1f3dfd2909114d43abefbf884bbdceda9f8ff7.svg" width="19"/>
#             Sikker betaling med GoMore
#           </a>
# </div>
# <div class="bt b--gray-7 collapse" id="q1">
# <div class="panel-body pt4 ph5 pb5">
# <h5 class="mb0">
#                 Kredit
#               </h5>
# <p class="mb3 text-gray-40">
#               Din betaling trækkes først 24 timer efter liftafgang.
#               </p>
# <h5 class="mb0">
#                 Garanti
#               </h5>
# <p class="mb3 text-gray-40">
#               Bliver liftet aflyst, sletter vi automatisk betalingen.
#               </p>
# <h5 class="mb0">
#                 Trygt
#               </h5>
# <p class="mb3 text-gray-40">
#               Se ratings og anbefalinger før du booker.
#               </p>
# <h5 class="mb0">
#                 Anbefalet
#               </h5>
# <p class="mb0 text-gray-40">
#               5 stjerner på Trustpilot. 500+ perfekte kundeanmeldelser.
#               </p>
# </div>
# </div>
# </div>
# </div>
# <div class="text-center">
# </div>
# </div>
# <div class="modal fade" id="route-modal">
# <div class="modal-dialog modal-dialog--wide">
# <div class="modal-content">
# <div class="modal-header bn">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <h4 class="modal-title f4 mb0">
#           Rute
#         </h4>
# </div>
# <div class="modal-body pa0">
# <div class="route-map" id="js-map"></div>
# </div>
# <div class="modal-footer bn text-left text-gray-60 f6">
# <span class="block">Distance: 51 km.</span>
# <span class="block" id="js-duration"></span>
# <span class="block">Bemærk: foreslået rute fra Google Maps. Den faktiske kan variere.</span>
# </div>
# </div>
# </div>
# </div>
# <div class="modal medium hide fade" data-backdrop="static" id="book">
# </div>
# <div class="modal fade" id="login">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <a class="close" data-dismiss="modal">×</a>
# <h3>Log ind for at kontakte Michael P.</h3>
# </div>
# <div class="modal-body">
# <form accept-charset="UTF-8" action="/users/sign_in" class="form-horizontal" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="7qn4QaOBIKPx8yQDMsGUKP+o/dGSklsTUSdioUxFamFEc7BM0HgKf4YILLYzxIMKYU0R2Vp72xrZHiscjHCY9Q=="/>
# <br class="hidden-xs"/>
# <div class="form-group">
# <label class="control-label col-md-4">
#             E-mail
#           </label>
# <div class="controls col-md-6">
# <input class="form-control" id="user_email" name="user[email]" type="email"/>
# </div>
# </div>
# <div class="form-group">
# <label class="control-label col-md-4">
#             Kodeord
#           </label>
# <div class="controls col-md-6">
# <input class="form-control" id="user_password" name="user[password]" type="password"/>
# </div>
# </div>
# <div class="form-group">
# <div class="controls col-md-6 col-md-offset-4">
# <div class="checkbox">
# <label>
# <input name="user[remember_me]" type="hidden" value="0"/><input id="user_remember_me" name="user[remember_me]" type="checkbox" value="1"/> Husk mig
#               </label>
# </div>
# </div>
# </div>
# <div class="form-group">
# <div class="controls col-md-8 col-md-offset-4">
# <input class="btn btn-success" data-disable-with="Log ind" name="commit" type="submit" value="Log ind"/>
# <br/><br/>
# <span class="small">
#               Ingen profil?
#               <a href="/users/sign_up">Opret gratis</a>
# <br/>
#               Glemt kodeord?
#               <a href="/users/password/new">Få et nyt</a>
# </span>
# </div>
# </div>
# <hr/>
# <div class="form-group">
# <label class="control-label col-md-4 hidden-xs">
#             Adgang med ét klik
#           </label>
# <div class="controls col-md-8">
# <a class="btn btn-lg btn-facebook" href="/users/auth/facebook">
# <i class="fa fa-facebook-square"></i>
#               Log ind med Facebook
# </a> </div>
# </div>
# </form> </div>
# </div>
# </div>
# </div>
# <div class="gmodal message fade" id="message-modal">
# <div class="gmodal-dialog">
# <div class="gmodal-content">
# <div class="gmodal-header">
# <a class="gmodal-close" data-dismiss="modal">×</a>
# <h4 class="gmodal-title mb0">
#           Send besked til Michael
#         </h4>
# </div>
# <div class="gmodal-body">
# <p>
# <span class="label label-info">Bemærk</span>
# <small>Det er ikke nok at sende en besked for at booke liftet. Husk aldrig at opfordre til eller acceptere betaling uden for GoMore.</small>
# </p>
# <div class="form-group">
# <label class="control-label">Din besked:</label>
# <div class="controls">
# <textarea class="form-control" id="message" name="message" placeholder="Skriv din besked her" rows="5" tabindex="1">
# </textarea>
# </div>
# </div>
# <div class="gmodal-actions">
# <a class="btn btn-default" data-dismiss="modal" href="#">Fortryd</a>
# <input class="btn btn-default btn-success send-btn" tabindex="2" type="submit" value="Send besked"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="gmodal fade" id="report">
# <div class="gmodal-dialog">
# <div class="gmodal-content">
# <form accept-charset="UTF-8" action="/accounts/:user_id/report_abuse" data-remote="true" method="post"><input name="utf8" type="hidden" value="✓"/>
# <input id="url" name="url" type="hidden" value="https://gomore.dk/rides/6573645"/>
# <input id="description" name="description" type="hidden"/>
# <div class="gmodal-header">
# <a class="gmodal-close" data-dismiss="modal">×</a>
# <h4 class="gmodal-title">
#               Rapportér et problem
#             </h4>
# <div class="gmodal-lead">
#               Dit svar deles kun med GoMore
#             </div>
# </div>
# <div class="gmodal-body">
# <label class="f-base">
#               Hvorfor rapporterer du dette?
#             </label>
# <textarea class="form-control mb3" id="message" name="message" placeholder="Beskriv problematikken her.." rows="5" tabindex="1">
# </textarea>
# <div class="mb5 text-gray-60">
#               Vi svarer personligt inden for 24 timer.
#             </div>
# <div class="gmodal-actions">
# <a class="btn btn-default" data-dismiss="modal" href="#">Fortryd</a>
# <input class="btn btn-default btn-success" tabindex="2" type="submit" value="Send anmeldelse"/>
# </div>
# </div>
# </form> </div>
# </div>
# </div>
# </div>
# <div class="modal fade" id="fraud-modal">
# <div class="modal-dialog">
# <div class="modal-content bg-transparent">
# <div class="modal-header text-center text-white bg-red pa5 br3-top-right br3-top-left">
# <img alt="" class="mb2" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_alert-f3faeed51476b84cb0e4856b60268451e6a8012d748c2867ab053238a15d9d62.svg" width="24"/>
# <h3>Lige et øjeblik</h3>
# <p>Du har skrevet noget, som ser ud til at være imod vores betingelser</p>
# </div>
# <div class="modal-body bg-white">
# <p class="text-gray-60">
# <span class="content-removed">
#             Vi har fjernet det, du har skrevet.
#           </span>
#             Bemærk at det er imod vores betingelser at opfordre til eller acceptere betaling uden for GoMore.
#         </p>
# <h5>Hvorfor betale online?</h5>
# <ul class="list-unstyled mb2">
# <li class="flex mb1 ml2 text-gray-60">
# <i class="fa fa-check mt1 mr2 text-green"></i>
#               Det gør bookinger mere pålidelige
#             </li>
# <li class="flex ml2 text-gray-60">
# <i class="fa fa-check mt1 mr2 text-green"></i>
#             Det er med til at betale for vores website, apps og kundeservice
#           </li>
# </ul>
# </div>
# <div class="modal-footer bg-brand-paper br3-bottom-left br3-bottom-right">
# <a class="btn btn-default btn-lg btn-block" data-dismiss="modal" href="#">Jeg forstår</a>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     window.supressPhoneValidationModal = true;
#   </script>
# <div>
# <div class="gmodal fade" data-show-dismiss="true" data-supress-phone-validation-modal="true" data-variant="generic" id="js-phone-validation-modal" role="dialog" tabindex="-1"></div>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="container">
# <div class="row flex flex-same-col-height">
# <div class="col-md-2 col-xs-12">
# <div class="badges mb5">
# <h5>Gratis apps</h5>
# <a class="badge-appstore badge-outline" href="https://itunes.apple.com/app/gomore/id671759668" target="_blank">
# <i class="fa fa-apple"></i><span class="badge-label">iPhone</span>
# </a>
# <a class="badge-playstore badge-outline" href="https://play.google.com/store/apps/details?id=dk.gomore" target="_blank">
# <i class="fa fa-android"></i><span class="badge-label">Android</span>
# </a>
# </div>
# </div>
# <div class="col-md-2 col-sm-3 col-xs-6 mt4 mt0-md">
# <h5>Firma</h5>
# <ul class="list-unstyled">
# <li><a href="/about">Om GoMore</a></li>
# <li><a href="/press">Presse</a></li>
# <li><a href="https://blog.gomore.dk">Blog</a></li>
# <li><a href="http://blog.gomore.dk/talent">Job</a></li>
# <li><a href="/support">Support</a></li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-3 col-xs-6 mt4 mt0-md">
# <h5>Samkørsel</h5>
# <ul class="list-unstyled">
# <li><a href="/rideshare/how">Sådan virker det</a></li>
# <li><a href="/how/drivers">Tilbyd eller find lift</a></li>
# <li><a href="/rideshare/safety">Sikkerhed</a></li>
# <li><a href="/rules">Regler</a></li>
# <li><a href="/samkoersel">Populære ruter</a></li>
# </ul>
# </div>
# <div class="col-md-2 col-sm-3 col-xs-6 mt4 mt0-md">
# <h5>Biludlejning</h5>
# <ul class="list-unstyled">
# <li><a href="/rental/how">Sådan virker det</a></li>
# <li><a href="/rental/owner">Udlej din bil</a></li>
# <li><a href="/rental">Lej biler</a></li>
# <li><a href="/rental/insurance">Forsikring</a></li>
# </ul>
# </div>
# <div class="col-md-4 col-sm-3 col-xs-6 mt4 mt0-md" id="latest">
# <h5>Seneste fra bloggen</h5>
# <div class="pr3 pr0-md" data-feed-url="https://blog.gomore.dk/feed" id="js-latest-blog"></div>
# </div>
# </div>
# <div class="disclaimer">
# <div class="row">
# <div class="col-xs-4 col-sm-5">
# <div class="inline pull-left mr4">
# <div class="language">
# <div class="dropup">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <img alt="Icon flag da" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_da-7dd6660b866d3303cf0fe75063ce05c028fa1af5cc4dc2fded5009ed86249ef7.png"/>
# </a>
# <ul class="dropdown-menu dropdown-menu-left">
# <li class="language-item">
# <a href="/locales/switch/en">
# <img alt="" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_en-7af5fac18fb74067a9e1b9024bfa60a2158e6ec4fa0954b34f76e10ac41444b4.png"/>
#             English
# </a> </li>
# <li class="divider"></li>
# <li class="language-item">
# <a href="https://gomore.se/">
# <img alt="" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_sv-36134ad3d906dcd898c3386cede769cd7565db5fc3c71884b831d205fe07e152.png"/>
#             gomore.se
# </a> </li>
# <li class="language-item">
# <a href="https://gomore.no/">
# <img alt="" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_no-42c23122dfdf07b44d66b676364ee2efc7248c7d7fbc14af5f690fff3fdf3082.png"/>
#             gomore.no
# </a> </li>
# <li class="language-item">
# <a href="https://amovens.com/">
# <img alt="" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_es-38297a600d8d8098958768f8dd9c5309fd5326f6b3c03758dadb918262e58d6a.png"/>
#             gomore.es
# </a> </li>
# <li class="language-item">
# <a href="https://gomore.fr/">
# <img alt="" src="https://d19xplwbp8p59b.cloudfront.net/assets/icon_flag_fr-bcc23e95aa9783177100cc3e2f2d2f5cb26e1918b8e2ca4fb771c3413dda0774.png"/>
#             gomore.fr
# </a> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hidden-xs">
#             © 2018 GoMore ApS
#             <a class="faded" href="/terms">Betingelser</a>
# <a class="faded hidden-sm hidden-md" href="/sitemap">Sitemap</a>
# </div>
# </div>
# <div class="col-xs-4 col-sm-2 text-center">
# <a class="btn-link" href="https://www.facebook.com/gomore.dk">
# <i class="fa fa-facebook fa-1-5x"></i>
# </a>
# <a class="btn-link" href="http://twitter.com/gomoreDK">
# <i class="fa fa-twitter fa-1-5x"></i>
# </a>
# <a class="btn-link" href="http://instagram.com/gomore.dk">
# <i class="fa fa-instagram fa-1-5x"></i>
# </a>
# </div>
# <div class="col-xs-4 col-sm-5">
# <div class="pull-right">
# <div class="inline hidden-xs">
# <i class="fa fa-cc-visa fa-1-5x mr3" title="VISA"></i>
# <i class="fa fa-cc-mastercard fa-1-5x" title="Mastercard"></i>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="outdated-notice" id="js-outdated">
# <h6 class="outdated-notice__heading">
#         Din browser er forældet
#       </h6>
# <p class="outdated-notice__notice">
#         Opdatér din browser for at se websitet korrekt
#
#         <a class="outdated-notice__update-btn" href="http://outdatedbrowser.com/" target="_blank">
#           Opdatér min browser nu
#         </a>
# </p>
# <p class="outdated-notice__close-container">
# <a class="outdated-notice__close-btn" href="#" title="Close">
#           ×
#         </a>
# </p>
# </div>
# <script src="https://d19xplwbp8p59b.cloudfront.net/assets/outdatedbrowser-2f60800674911506881a7192f1d9921be6728d28f59b8cf400dcee183102b8c9.js"></script>
# <script src="https://d19xplwbp8p59b.cloudfront.net/assets/application-38af5aa020fb3901a2d630aaaf0d317bbc2739581d7cb06c3c5cbab964a7681b.js"></script>
# <script src="https://d19xplwbp8p59b.cloudfront.net/assets/translations/da-2bbe3b610419c03b7d7c0289947917b38bf7decdc9ac828a7ae110d8efa5f4e4.js"></script>
# <script type="text/javascript">
#   window.railsEnv = "production";
#
#   window.currencies = new CurrencyCollection();
#   window.currencies.reset([{"id":1,"code":"DKK","symbol":"kr","display":"DKK","display_align":"left","bank_account_no":50100001516164,"step":5},{"id":3,"code":"SEK","symbol":"kr","display":"SEK","display_align":"left","bank_account_no":121792,"step":5},{"id":4,"code":"NOK","symbol":"kr","display":"NOK","display_align":"left","bank_account_no":121677,"step":5},{"id":5,"code":"EUR","symbol":"€","display":"€","display_align":"right","step":1}]);
#
#   window.countries = new CountryCollection();
#   window.countries.reset([{"id":1,"active":true,"name":"Danmark","key":"denmark","locale_id":1,"currency_id":1,"timezone":"Europe/Copenhagen","handle_fee_rate":12.5,"handle_fee_ceiling_factor":100,"handle_fee_maximum":null,"code":"DK","center":[56.26392,10.501785],"bounds":{"south_west":[54.70793299539553,6.73725100341801],"north_east":[57.7591089598695,14.26631899658207]},"blog_feed":"https://blog.gomore.dk/feed","blog_url":"https://blog.gomore.dk","help_url":"http://help.gomore.dk","points_help_url":"http://help.gomore.dk/collection/780-gomore-point","facebook_page":"https://www.facebook.com/gomore.dk","referral_page":"https://gomore.dk/invite","drive_page":"https://gomore.dk/drive","rules_page":"https://gomore.dk/rental/rules","rental_guide":"https://gomore.dk/rental/guide#rental-contract","twitter_account":"gomoreDK","instagram_account":"gomore.dk","company_name":"GoMore ApS","company_address":"Kompagnistræde 20C, 3. sal, 1208 København K., Danmark","site_name":"GoMore","support_mail":"support@gomore.dk","support_page":"https://gomore.dk/support","experience_mail":"experience@gomore.dk","support_phone":"71 99 58 00","noreply_mail":"GoMore \u003cnoreply@gomore.com\u003e","story_mail":"story@gomore.dk","leasing_mail":"leasing@gomore.dk","leasing_phone":"71 99 58 80","coffee_company":"Q8","calling_code":45,"sms_sender":"GoMore","beacon":{"enabled":true,"form_id":"0bd16361-6341-11e5-8846-0e599dc12a51","base_url":"https://gomoredk.helpscoutdocs.com"},"widgets":{"location_example":{"name":"RUC - Roskilde Universitet","address":"Universitetsvej 1, 4000 Roskilde","latitude":55.652912,"longitude":12.143393},"rides":{"from":{"key":"aarhus","latitude":56.1714126,"longitude":10.1409236},"to":{"key":"copenhagen","latitude":55.6712674,"longitude":12.5608388}}},"location_examples":{"rideshare":{"from":"aarhus","to":"copenhagen"},"events":{"city":"Horsens","address":"Langmarksvej 53, 8700 Horsens"}},"rideshare_settings":{"max_seats":8,"min_price":0,"max_price":500000,"rental_ad_max_price":40000,"search":{"parameters":{"within":"10"}},"quick_booking_default":true,"motorway_indicator":false,"ceiling_factor":100,"credit_card_fee":275,"default_show_fully_booked_rides_in_search":true},"rental_ad_boost_prices":{"24":2900,"72":5900,"168":9900,"720":29900},"deposit":{"max_amount":30000},"payment":{"reg_no":true,"bank_reg_no_format":"^(\\d *){3}\\d$","bank_account_no_format":"^(\\d *){6}\\d$|^(\\d *){9}\\d$"},"ssn_format":"^\\d{10}$","stats":{"ride_seats":"seats_today"},"seo_routes":["aarhus-koebenhavn","koebenhavn-aarhus","aalborg-aarhus","aarhus-aalborg","odense-koebenhavn","koebenhavn-odense","aalborg-koebenhavn","koebenhavn-aalborg","esbjerg-koebenhavn","koebenhavn-esbjerg","odense-aarhus","aarhus-odense","malmoe-koebenhavn","koebenhavn-malmoe"],"rental_ad_seo_type":"biludlejning","car_name_and_model_widget":"name_and_model_input","google_browser_key":"AIzaSyC9dDPdYb7lubRtVuKvaWGadjk9QzyXF7o","microsoft_client_id":"e6fcb231-e701-4038-83e3-c51eb0a0b606","yahoo_client_id":"dj0yJmk9dGd3QlQxNTNKMUlNJmQ9WVdrOVdYSkZXRWRRTjJVbWNHbzlNQS0tJnM9Y29uc3VtZXJzZWNyZXQmeD0zYg--","leasing_company":"LeasePlan","leasing_km_included_default":24000,"org_no":"35865497","max_cumulative_points_rental_value":1000000,"max_points_balance_rental_value":300000,"rental_point_value":100,"loyalty_points_bonus":{"booking":10,"rental":2.5},"point_gifts":{"minimum_referred_booking_value":5000,"referred_ride_resolved":100,"referred_booking_resolved":50,"minimum_referred_rental_value":20000,"referred_rental_resolved":150,"referred_rental_resolved_as_owner":300,"user_signed_up":100},"example_data":{"address":"Kompagnistræde 20C, 1. th.","social_security_number":"010180-1234"},"xero":{"enabled":true,"creditor_country_account_code":1111,"creditor_user_account_code":5640,"payment_acount_code":5824,"branding_theme_id":"48f59738-1247-48d0-8da0-0fb2865ca50e"},"ridesharing_insurance_partner":{"name":"TBD","phone":"TBD","phone_pretty":"TBD"},"merchant_number":1422053,"ga_id":"UA-22452306- ...
#
#   window.currentCountry = countries.get(1);
#   window.currentHost = new Host({"name":"gomore.dk"});
#
#
#   window.appConfig = {
#     supportedCallingCodes: [1,212,213,262,269,298,299,30,31,32,33,34,350,351,352,353,354,355,356,357,358,359,36,370,371,372,373,374,375,376,377,378,379,380,381,382,383,385,386,387,389,39,40,41,420,421,423,43,44,45,46,47,48,49,502,504,505,506,507,508,51,52,53,54,55,56,57,58,590,591,592,593,594,596,598,61,65,66,681,687,689,886,972],
#     epayUseCallback: true,
#     epayInstantCallbackURL: "https://gomore.dk/epay/callback",
#     epayCssUrls: {"regular_desktop":"https://gomore.dk/epay_standard.css","narrow_desktop":"https://gomore.dk/epay_standard_modal.css","regular_mobile":"https://gomore.dk/epay_mobile.css","narrow_mobile":"https://gomore.dk/epay_mobile.css"},
#     facebookAppId: 172475122803857
#   };
#
#   window.timezone = "Europe/Copenhagen";
# </script>
# <script type="text/javascript">
#       I18n.locale = 'da';
#       I18n.globalOptions = $.parseJSON('{\"site_name\":\"GoMore\",\"site_url\":\"gomore.dk\",\"coffee_company\":\"Q8\"}');
#
#       initialization.schedule("modal");
#       initialization.schedule("facebook");
#       initialization.schedule("twitter");
#         initialization.execute("smartbanner");
#       initialization.execute("moment");
#       initialization.schedule("datepicker");
#         initialization.schedule("beacon");
#       $(document).ready(function() {
#         outdatedBrowser({
#           bgColor: '#f7972a',
#           color: '#fff',
#           lowerThan: 'IE11', // show notice when < IE11
#           languagePath: ''
#         });
#       });
#     </script>
# <script src="https://d19xplwbp8p59b.cloudfront.net/assets/beacon-d6fd514193211c12f7234e407fda8a44eab695f4d31ae2f30f032bc57cae1497.js"></script>
# <script src="https://maps.google.com/maps/api/js?libraries=geometry,places&amp;key=AIzaSyC9dDPdYb7lubRtVuKvaWGadjk9QzyXF7o&amp;language=da&amp;region=DK"></script>
# <script src="https://ssl.ditonlinebetalingssystem.dk/integration/ewindow/paymentwindow.js"></script>
# <script>
# //<![CDATA[
# initialization.schedule('gmodal');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('reportIssue');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('phoneValidation');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('gmodal');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('ridesShow');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('reportIssue');
# //]]>
# </script><script>
# //<![CDATA[
# initialization.schedule('phoneValidation');
# //]]>
# </script>
# </body>
# </html>
